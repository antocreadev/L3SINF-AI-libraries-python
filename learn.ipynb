# %%
import pandas as pd
import seaborn as sns
data = pd.read_csv('data.csv')

# %%
print(data.get("island")) # or data["island"] -> get column
# Out:
# 0      Torgersen
# 1      Torgersen
# 2      Torgersen
# 3      Torgersen
# 4      Torgersen
#          ...
# 339        Dream
# 340        Dream
# 341        Dream
# 342        Dream
# 343        Dream
# Name: island, Length: 344, dtype: object

# %%
data.iloc[1] # -> get row
# Out:
# species                 Adelie
# island               Torgersen
# bill_length_mm            39.5
# bill_depth_mm             17.4
# flipper_length_mm        186.0
# body_mass_g             3800.0
# sex                     female
# year                      2007
# Name: 1, dtype: object

# %%
print(data.get("island").unique()) # -> get unique values
# Out:
# ['Torgersen' 'Biscoe' 'Dream']

# %%
print(data.get("island").value_counts()) # -> get unique values and count
# print(data.get("island").value_counts().Biscoe)
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
data.dtypes # -> get data types
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# year                   int64
# dtype: object

# %%
print(data.get("island").value_counts(normalize=True)) # -> get unique values and count in percentage
# Out:
# island
# Biscoe       0.488372
# Dream        0.360465
# Torgersen    0.151163
# Name: proportion, dtype: float64

# %%
data.describe() # -> get statistics
# count -> number of values
# mean -> average : sum of values / number of values
# std -> standard deviation : how much the values are spread out 
# min -> minimum value 
# 25% -> 25% percentile : 25% of the values are less than this value
# 50% -> 50% percentile
# 75% -> 75% percentile
# max -> maximum value
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   344.000000
# mean   2008.029070
# std       0.818356
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %%
data.select_dtypes(exclude=['object']) # -> get only numeric columns
data.select_dtypes(include=['float64', 'int64']) # -> get only numeric columns
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  year
# 0              39.1           18.7              181.0       3750.0  2007
# 1              39.5           17.4              186.0       3800.0  2007
# 2              40.3           18.0              195.0       3250.0  2007
# 3               NaN            NaN                NaN          NaN  2007
# 4              36.7           19.3              193.0       3450.0  2007
# ..              ...            ...                ...          ...   ...
# 339            55.8           19.8              207.0       4000.0  2009
# 340            43.5           18.1              202.0       3400.0  2009
# 341            49.6           18.2              193.0       3775.0  2009
# 342            50.8           19.0              210.0       4100.0  2009
# 343            50.2           18.7              198.0       3775.0  2009
#
# [344 rows x 5 columns]

# %%
data.isna() # -> get null values
# get all value no null
data.dropna() # -> drop all rows with null values
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 4       Adelie  Torgersen            36.7           19.3              193.0
# 5       Adelie  Torgersen            39.3           20.6              190.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
data["sex"].isna() # -> get null values in column
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: sex, Length: 344, dtype: bool

# %%
data[data["sex"].isna()==False] # -> get rows with no null values in column
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 4       Adelie  Torgersen            36.7           19.3              193.0
# 5       Adelie  Torgersen            39.3           20.6              190.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
data[data["sex"].isna()==True] # -> get rows with null values in column
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# 47   Adelie      Dream            37.5           18.9              179.0
# 178  Gentoo     Biscoe            44.5           14.3              216.0
# 218  Gentoo     Biscoe            46.2           14.4              214.0
# 256  Gentoo     Biscoe            47.3           13.8              216.0
# 268  Gentoo     Biscoe            44.5           15.7              217.0
# 271  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g  sex  year
# 3            NaN  NaN  2007
# 8         3475.0  NaN  2007
# ...

# %%
# get summ of drop null values
data.shape[0] - data.dropna().shape[0]
# Out:
# 11

# %%
data[data['bill_depth_mm'].isna()==True] # -> get rows with null values in column
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 271  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g  sex  year
# 3            NaN  NaN  2007
# 271          NaN  NaN  2009

# %%
# delete rows with null values
data.dropna(subset=['bill_depth_mm'], inplace=True)  # -> save changes in data

data[data['bill_depth_mm'].isna()==True] # -> get rows with null values in column
# Out:
# Empty DataFrame
# Columns: [species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year]
# Index: []

# %%
data.select_dtypes(exclude=['object']).corr() # -> get correlation between numeric columns
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
# year                     0.054545      -0.060354           0.169675
#
#                    body_mass_g      year
# bill_length_mm        0.595110  0.054545
# bill_depth_mm        -0.471916 -0.060354
# flipper_length_mm     0.871202  0.169675
# body_mass_g           1.000000  0.042209
# year                  0.042209  1.000000

# %%
data["body_mass_g"]>6000 # -> get boolean values
# Out:
# 0      False
# 1      False
# 2      False
# 4      False
# 5      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: body_mass_g, Length: 342, dtype: bool

# %%
data[data["body_mass_g"]>6000] # -> get rows with boolean values
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 169  Gentoo  Biscoe            49.2           15.2              221.0
# 185  Gentoo  Biscoe            59.6           17.0              230.0
#
#      body_mass_g   sex  year
# 169       6300.0  male  2007
# 185       6050.0  male  2007

# %%
index = data[data["body_mass_g"]>6000].index
index
# Out:
# Index([169, 185], dtype='int64')

# %%
dt = data.drop(index, inplace=False) # -> delete rows with index
dt[dt["body_mass_g"]>6000] # -> get rows with boolean values
# Out:
# Empty DataFrame
# Columns: [species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year]
# Index: []

# %%
# get only sex column
dt2 = data.select_dtypes(exclude=["object"])
# add column 
dt2["sex"] = data["sex"]

# group by sex
dt2.groupby(by=["sex"]).mean()
# Out:
#         bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# sex
# female       42.096970      16.425455         197.363636  3862.272727
# male         45.854762      17.891071         204.505952  4545.684524
#
#                year
# sex
# female  2008.042424
# male    2008.041667

# %%
data.dropna(inplace=True)

# %%
data["sex"] = data["sex"].apply(lambda e : 0 if e =="male" else 1)
data
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 4       Adelie  Torgersen            36.7           19.3              193.0
# 5       Adelie  Torgersen            39.3           20.6              190.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g  sex  year
# ...

# %%
data.sort_values(by=["body_mass_g", "bill_length_mm"], ascending=False) # -> sort by column
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 169     Gentoo  Biscoe            49.2           15.2              221.0
# 185     Gentoo  Biscoe            59.6           17.0              230.0
# 229     Gentoo  Biscoe            51.1           16.3              220.0
# 269     Gentoo  Biscoe            48.8           16.2              222.0
# 263     Gentoo  Biscoe            49.8           15.9              229.0
# ..         ...     ...             ...            ...                ...
# 54      Adelie  Biscoe            34.5           18.1              187.0
# 98      Adelie   Dream            33.1           16.1              178.0
# 58      Adelie  Biscoe            36.5           16.6              181.0
# 64      Adelie  Biscoe            36.4           17.1              184.0
# 314  Chinstrap   Dream            46.9           16.6              192.0
#
#      body_mass_g  sex  year
# 169       6300.0    0  2007
# 185       6050.0    0  2007
# ...

# %%
data["bins"] = pd.cut(data["body_mass_g"], bins=2, labels=["toto1", "toto2"]) # -> cut column to 3 bins
# bins -> number of bins
# labels -> labels of bins
data["bins"].value_counts()
# Out:
# bins
# toto1    221
# toto2    112
# Name: count, dtype: int64

# %%
data.plot.scatter(x="body_mass_g", y="bill_length_mm") # -> scatter plot
# Out:
# <Axes: xlabel='body_mass_g', ylabel='bill_length_mm'>

# %%
sns.scatterplot(x=data["body_mass_g"], y=data["bill_length_mm"], hue=data["species"]) # -> scatter plot
# Out:
# <Axes: xlabel='body_mass_g', ylabel='bill_length_mm'>

# %%
# sns pariplot with hue 
sns.pairplot(data, hue="species")

# %%
sns.histplot(data=data, x="bill_length_mm",bins=30, hue="species") # -> histogram
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>
