# %%
import pandas as pd
import matplotlib.pyplot as plt
# read cars.csv
data_gaz = pd.read_csv("./data/gaz.csv", dtype={'INSEE': str}, index_col="INSEE")
# dtype={'INSEE': str} : force le type de la colonne INSEE à str
# index_col="INSEE" : utilise la colonne INSEE comme index
data_gaz
# Out:
#                        Commune  Agriculture  Autres transports  \
# INSEE
# 01001  L'ABERGEMENT-CLEMENCIAT  3711.425991                NaN
# 01002    L'ABERGEMENT-DE-VAREY   475.330205                NaN
# 01004        AMBERIEU-EN-BUGEY   499.043526         212.577908
# 01005      AMBERIEUX-EN-DOMBES  1859.160954                NaN
# 01006                  AMBLEON   448.966808                NaN
# ...                        ...          ...                ...
# 95676       VILLERS-EN-ARTHIES  1628.065094                NaN
# 95678            VILLIERS-ADAM   698.630772                NaN
# 95680          VILLIERS-LE-BEL   107.564967                NaN
# 95682          VILLIERS-LE-SEC  1090.890170                NaN
# 95690      WY-DIT-JOLI-VILLAGE  1495.103542                NaN
#
#        Autres transports international  CO2 biomasse hors-total      Déchets  \
# INSEE
# 01001                              NaN               432.751835   101.430476
# ...

# %%
data_gaz.shape
# Out:
# (35789, 15)

# %%
data_gaz.dtypes
# Out:
# Commune                             object
# Agriculture                        float64
# Autres transports                  float64
# Autres transports international    float64
# CO2 biomasse hors-total            float64
# Déchets                            float64
# Energie                            float64
# Industrie hors-énergie             float64
# Résidentiel                        float64
# Routier                            float64
# Tertiaire                          float64
# nom_commune_postal                  object
# nom_departement                     object
# latitude                           float64
# longitude                          float64
# dtype: object

# %%
data_gaz.dtypes.value_counts()
# Out:
# float64    12
# object      3
# Name: count, dtype: int64

# %%
data_gaz.isna().sum()
# Out:
# Commune                                0
# Agriculture                           62
# Autres transports                  25811
# Autres transports international    32898
# CO2 biomasse hors-total                0
# Déchets                                6
# Energie                             1301
# Industrie hors-énergie              1301
# Résidentiel                            6
# Routier                               19
# Tertiaire                              0
# nom_commune_postal                     0
# nom_departement                        0
# latitude                               0
# longitude                              0
# dtype: int64

# %%
data_gaz.describe()
# Out:
#         Agriculture  Autres transports  Autres transports international  \
# count  35727.000000        9978.000000                     2.891000e+03
# mean    2460.268448         654.983149                     7.692345e+03
# std     2927.247535        9233.277367                     1.137643e+05
# min        0.003432           0.000204                     3.972950e-04
# 25%      797.739016          52.569620                     1.005097e+01
# 50%     1559.581679         106.813577                     1.992434e+01
# 75%     3008.684900         237.404560                     3.298311e+01
# max    98949.317760      513140.971691                     3.303394e+06
#
#        CO2 biomasse hors-total        Déchets       Energie  \
# count             35789.000000   35783.000000  3.448800e+04
# mean               1774.521820     410.896773  6.625899e+02
# std                7872.266877    4122.986976  2.645648e+04
# min                   3.758088       0.132243  2.354558e+00
# ...

# %%
data_gaz[data_gaz['Déchets'].isna()]
# Out:
#                         Commune  Agriculture  Autres transports  \
# INSEE
# 55039     BEAUMONT-EN-VERDUNOIS   593.042434                NaN
# 55050                 BEZONVAUX   589.326652                NaN
# 55139    CUMIERES-LE-MORT-HOMME   586.574227                NaN
# 55189   FLEURY-DEVANT-DOUAUMONT   593.883388          88.146218
# 55239    HAUMONT-PRES-SAMOGNEUX   601.517905                NaN
# 55307  LOUVEMONT-COTE-DU-POIVRE   593.606726                NaN
#
#        Autres transports international  CO2 biomasse hors-total  Déchets  \
# INSEE
# 55039                              NaN                39.072201      NaN
# 55050                              NaN                 7.963334      NaN
# 55139                              NaN                15.684858      NaN
# 55189                              NaN               106.135840      NaN
# 55239                              NaN                 7.608032      NaN
# ...

# %%
data_gaz[data_gaz['Déchets'] > 2e+5]
# Out:
#                  Commune  Agriculture  Autres transports  \
# INSEE
# 13039        FOS-SUR-MER   305.092893        1893.383189
# 38468  SALAISE-SUR-SANNE   887.127809         302.540259
#
#        Autres transports international  CO2 biomasse hors-total  \
# INSEE
# 13039                     17227.234585             50891.367548
# 38468                        12.834376              9694.213909
#
#              Déchets       Energie  Industrie hors-énergie  Résidentiel  \
# INSEE
# 13039  275500.374439  2.296711e+06            6.765119e+06  9466.388806
# 38468  221513.845802  2.093202e+03            1.124486e+05  5538.759328
#
#             Routier     Tertiaire nom_commune_postal   nom_departement  \
# INSEE
# 13039  74631.401993  42068.140058        FOS SUR MER  Bouches-du-Rhône
# 38468  28412.101105   8155.445605  SALAISE SUR SANNE             Isère
#
#         latitude  longitude
# INSEE
# 13039  43.455681   4.904521
# 38468  45.344251   4.808605

# %%
data_gaz[data_gaz['Agriculture'].isna()]
# Out:
#                      Commune  Agriculture  Autres transports  \
# INSEE
# 01026         BAGE-LE-CHATEL          NaN                NaN
# 10294                POLIGNY          NaN                NaN
# 14022               ASNELLES          NaN                NaN
# 29238              ROSCANVEL          NaN          39.653211
# 31157                CUGNAUX          NaN                NaN
# ...                      ...          ...                ...
# 92064            SAINT-CLOUD          NaN         499.838509
# 92071                 SCEAUX          NaN         262.438419
# 92073               SURESNES          NaN         247.336505
# 92075                 VANVES          NaN          79.711550
# 92078  VILLENEUVE-LA-GARENNE          NaN          51.592570
#
#        Autres transports international  CO2 biomasse hors-total      Déchets  \
# INSEE
# 01026                              NaN               558.461375   113.067871
# ...

# %%
# data_gaz.sort_values(by="Agriculture", ascending=True).index[0:2]
data_gaz.nsmallest(2, 'Agriculture').index # plus rapide
# Out:
# Index(['01427', '62602'], dtype='object', name='INSEE')

# %%
data_gaz[data_gaz['Autres transports international'] > 3e+5]
# Out:
#                    Commune  Agriculture  Autres transports  \
# INSEE
# 06088                 NICE   305.445236      225204.545951
# 13054            MARIGNANE   240.561325      245375.418650
# 31069              BLAGNAC   397.377112      210157.688544
# 59183            DUNKERQUE   811.390947        3859.548994
# 68224             MULHOUSE   499.870240       54193.005415
# 69299   COLOMBIER-SAUGNIEU  1611.426327      270757.665000
# 76351             LE HAVRE  1168.274940       17358.962736
# 77282            MAUREGARD   733.910161      133699.072712
# 77291     LE MESNIL-AMELOT   782.183307      133834.090767
# 77294           MITRY-MORY  1912.746387       89815.529858
# 91479  PARAY-VIEILLE-POSTE    59.178585      513140.971691
# 91689              WISSOUS   824.534458      308100.163825
# 93073   TREMBLAY-EN-FRANCE  1362.351634       45251.869710
# 95527     ROISSY-EN-FRANCE  1150.313505       44883.982753
#
#        Autres transports international  CO2 biomasse hors-total  \
# ...

# %%
data_gaz.sort_values(by="Routier", ascending=False)[data_gaz['Routier'] > 1e+5][0:2]
# .head(2)
# Out:
# /var/folders/_c/0ljn6xbs20x7kt0d11t1n6_80000gn/T/ipykernel_1910/3256451644.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_gaz.sort_values(by="Routier", ascending=False)[data_gaz['Routier'] > 1e+5][0:2]
#         Commune  Agriculture  Autres transports  \
# INSEE
# 31555  TOULOUSE  1434.045233        4482.980062
# 06088      NICE   305.445236      225204.545951
#
#        Autres transports international  CO2 biomasse hors-total  \
# INSEE
# 31555                     1.307927e+02            576394.181208
# 06088                     1.003572e+06            169338.333391
#
#              Déchets       Energie  Industrie hors-énergie    Résidentiel  \
# INSEE
# 31555   88863.732538  91549.914092           277062.573234  410675.902028
# 06088  124232.948837  11866.971015            35893.648946  252857.325855
#
#              Routier      Tertiaire nom_commune_postal  nom_departement  \
# INSEE
# ...
